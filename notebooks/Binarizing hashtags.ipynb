# %% [markdown]
# # Binarizing hashtags
#
# In this notebook, we'll load the CSV for binarizing hashtags and process it. Then we'll save it into another CSV to later concatenate it with the rest of the dataset.

# %%
import numpy as np
import pandas as pd
import multiprocessing as mp
from sklearn.preprocessing import MultiLabelBinarizer

# %%
data = pd.read_csv('../data/hashtags_for_binarizer.csv')

# %%
data.shape
# Out:
# (3827022, 6)

# %%
data.head()
# Out:
#    week             user  tweets                        hashtags mentions  \
# 0    33  000000000000111       1  internetmarketing|internet|cel      NaN
# 1    32        0000001xx       1                        tinychat      NaN
# 2    28     000000knight       2             Ebuyer845|Ebuyer478      NaN
# 3    29     000000knight       1                       Ebuyer111      NaN
# 4    30     000000knight       1                       Ebuyer355      NaN
#
#                                                 urls
# 0                                http://wefollow.com
# 1                   http://tinychat.com/stickamraids
# 2  http://snurl.com/ebuyer1|http://snurl.com/ebuyer2
# 3                            http://sn.im/ebuyer_sat
# 4                            http://sn.im/ebuyer_sun

# %% [markdown]
# Now use the binarizer to process the hashtags column. We need to map the strings to arrays of hashtags.

# %%
# %%time
bin_columns = MultiLabelBinarizer(sparse_output=True).fit_transform(data['hashtags'].apply(lambda x: x.split('|')))
# Out:
# CPU times: user 21.3 s, sys: 985 ms, total: 22.3 s
# Wall time: 22.4 s

# %%
bin_columns.shape
# Out:
# (3827022, 1169693)

# %% [markdown]
# Get the number of rows with 1 for each hashtags. We will drop columns that have very few rows with 1.

# %%
hashtag_usage = bin_columns.sum(0)

# %%
# %%time
columns_with_high_usage = bin_columns[:, np.where(hashtag_usage >= 200)[0]]
columns_with_low_usage = bin_columns[:, np.where(hashtag_usage < 200)[0]]
# Out:
# CPU times: user 7.58 s, sys: 4.41 s, total: 12 s
# Wall time: 12.4 s

# %%
has_other_hashtags = columns_with_low_usage.sum(1).astype(bool).astype(int)

# %%
columns_with_high_usage.shape
# Out:
# (3827022, 4887)

# %% [markdown]
# This leaves us with `4887` columns for hashtags plus one for other hashtags. These are the hashtags that appear in at least 100 tweets. Now we need to drop the original `hashtags` column and insert the new columns.

# %%
data = data.drop('hashtags', axis=1).to_sparse(fill_value=0)

# %%
data['hashtag_other'] = pd.SparseSeries(np.asarray(has_other_hashtags).reshape(-1), fill_value=0)

# %%
# %%time
num_columns = columns_with_high_usage.shape[1]
for i in range(num_columns):
    print('inserting column', i, '/', num_columns)
    data['hashtag_' + str(i)] = pd.SparseSeries(columns_with_high_usage[:, i].toarray().reshape(-1), fill_value=0)
# Out:
# inserting column 0 / 4887
# inserting column 1 / 4887
# inserting column 2 / 4887
# inserting column 3 / 4887
# inserting column 4 / 4887
# inserting column 5 / 4887
# inserting column 6 / 4887
# inserting column 7 / 4887
# inserting column 8 / 4887
# inserting column 9 / 4887
# inserting column 10 / 4887
# inserting column 11 / 4887
# inserting column 12 / 4887
# inserting column 13 / 4887
# inserting column 14 / 4887
# inserting column 15 / 4887
# inserting column 16 / 4887
# inserting column 17 / 4887
# inserting column 18 / 4887
# inserting column 19 / 4887
# inserting column 20 / 4887
# inserting column 21 / 4887
# inserting column 22 / 4887
# inserting column 23 / 4887
# inserting column 24 / 4887
# inserting column 25 / 4887
# inserting column 26 / 4887
# inserting column 27 / 4887
# inserting column 28 / 4887
# inserting column 29 / 4887
# inserting column 30 / 4887
# inserting column 31 / 4887
# inserting column 32 / 4887
# inserting column 33 / 4887
# inserting column 34 / 4887
# inserting column 35 / 4887
# inserting column 36 / 4887
# inserting column 37 / 4887
# inserting column 38 / 4887
# inserting column 39 / 4887
# inserting column 40 / 4887
# inserting column 41 / 4887
# inserting column 42 / 4887
# inserting column 43 / 4887
# inserting column 44 / 4887
# inserting column 45 / 4887
# inserting column 46 / 4887
# inserting column 47 / 4887
# inserting column 48 / 4887
# inserting column 49 / 4887
# inserting column 50 / 4887
# inserting column 51 / 4887
# inserting column 52 / 4887
# inserting column 53 / 4887
# inserting column 54 / 4887
# inserting column 55 / 4887
# inserting column 56 / 4887
# inserting column 57 / 4887
# inserting column 58 / 4887
# inserting column 59 / 4887
# inserting column 60 / 4887
# inserting column 61 / 4887
# inserting column 62 / 4887
# inserting column 63 / 4887
# inserting column 64 / 4887
# inserting column 65 / 4887
# inserting column 66 / 4887
# inserting column 67 / 4887
# inserting column 68 / 4887
# inserting column 69 / 4887
# inserting column 70 / 4887
# inserting column 71 / 4887
# inserting column 72 / 4887
# inserting column 73 / 4887
# inserting column 74 / 4887
# inserting column 75 / 4887
# inserting column 76 / 4887
# inserting column 77 / 4887
# inserting column 78 / 4887
# inserting column 79 / 4887
# inserting column 80 / 4887
# inserting column 81 / 4887
# inserting column 82 / 4887
# inserting column 83 / 4887
# inserting column 84 / 4887
# inserting column 85 / 4887
# inserting column 86 / 4887
# inserting column 87 / 4887
# inserting column 88 / 4887
# inserting column 89 / 4887
# inserting column 90 / 4887
# inserting column 91 / 4887
# inserting column 92 / 4887
# inserting column 93 / 4887
# inserting column 94 / 4887
# inserting column 95 / 4887
# inserting column 96 / 4887
# inserting column 97 / 4887
# inserting column 98 / 4887
# inserting column 99 / 4887
# inserting column 100 / 4887
# inserting column 101 / 4887
# inserting column 102 / 4887
# inserting column 103 / 4887
# inserting column 104 / 4887
# inserting column 105 / 4887
# inserting column 106 / 4887
# inserting column 107 / 4887
# inserting column 108 / 4887
# inserting column 109 / 4887
# inserting column 110 / 4887
# inserting column 111 / 4887
# inserting column 112 / 4887
# inserting column 113 / 4887
# inserting column 114 / 4887
# inserting column 115 / 4887
# inserting column 116 / 4887
# inserting column 117 / 4887
# inserting column 118 / 4887
# inserting column 119 / 4887
# inserting column 120 / 4887
# inserting column 121 / 4887
# inserting column 122 / 4887
# inserting column 123 / 4887
# inserting column 124 / 4887
# inserting column 125 / 4887
# inserting column 126 / 4887
# inserting column 127 / 4887
# inserting column 128 / 4887
# inserting column 129 / 4887
# inserting column 130 / 4887
# inserting column 131 / 4887
# inserting column 132 / 4887
# inserting column 133 / 4887
# inserting column 134 / 4887
# inserting column 135 / 4887
# inserting column 136 / 4887
# inserting column 137 / 4887
# inserting column 138 / 4887
# inserting column 139 / 4887
# inserting column 140 / 4887
# inserting column 141 / 4887
# inserting column 142 / 4887
# inserting column 143 / 4887
# inserting column 144 / 4887
# inserting column 145 / 4887
# inserting column 146 / 4887
# inserting column 147 / 4887
# inserting column 148 / 4887
# inserting column 149 / 4887
# inserting column 150 / 4887
# inserting column 151 / 4887
# inserting column 152 / 4887
# inserting column 153 / 4887
# inserting column 154 / 4887
# inserting column 155 / 4887
# inserting column 156 / 4887
# inserting column 157 / 4887
# inserting column 158 / 4887
# inserting column 159 / 4887
# inserting column 160 / 4887
# inserting column 161 / 4887
# inserting column 162 / 4887
# inserting column 163 / 4887
# inserting column 164 / 4887
# inserting column 165 / 4887
# inserting column 166 / 4887
# inserting column 167 / 4887
# inserting column 168 / 4887
# inserting column 169 / 4887
# inserting column 170 / 4887
# inserting column 171 / 4887
# inserting column 172 / 4887
# inserting column 173 / 4887
# inserting column 174 / 4887
# inserting column 175 / 4887
# inserting column 176 / 4887
# inserting column 177 / 4887
# inserting column 178 / 4887
# inserting column 179 / 4887
# inserting column 180 / 4887
# inserting column 181 / 4887
# inserting column 182 / 4887
# inserting column 183 / 4887
# inserting column 184 / 4887
# inserting column 185 / 4887
# inserting column 186 / 4887
# inserting column 187 / 4887
# inserting column 188 / 4887
# inserting column 189 / 4887
# inserting column 190 / 4887
# inserting column 191 / 4887
# inserting column 192 / 4887
# inserting column 193 / 4887
# inserting column 194 / 4887
# inserting column 195 / 4887
# inserting column 196 / 4887
# inserting column 197 / 4887
# inserting column 198 / 4887
# inserting column 199 / 4887
# inserting column 200 / 4887
# inserting column 201 / 4887
# inserting column 202 / 4887
# inserting column 203 / 4887
# inserting column 204 / 4887
# inserting column 205 / 4887
# inserting column 206 / 4887
# inserting column 207 / 4887
# inserting column 208 / 4887
# inserting column 209 / 4887
# inserting column 210 / 4887
# inserting column 211 / 4887
# inserting column 212 / 4887
# inserting column 213 / 4887
# inserting column 214 / 4887
# inserting column 215 / 4887
# inserting column 216 / 4887
# inserting column 217 / 4887
# inserting column 218 / 4887
# inserting column 219 / 4887
# inserting column 220 / 4887
# inserting column 221 / 4887
# inserting column 222 / 4887
# inserting column 223 / 4887
# inserting column 224 / 4887
# inserting column 225 / 4887
# inserting column 226 / 4887
# inserting column 227 / 4887
# inserting column 228 / 4887
# inserting column 229 / 4887
# inserting column 230 / 4887
# inserting column 231 / 4887
# inserting column 232 / 4887
# inserting column 233 / 4887
# inserting column 234 / 4887
# inserting column 235 / 4887
# inserting column 236 / 4887
# inserting column 237 / 4887
# inserting column 238 / 4887
# inserting column 239 / 4887
# inserting column 240 / 4887
# inserting column 241 / 4887
# inserting column 242 / 4887
# inserting column 243 / 4887
# inserting column 244 / 4887
# inserting column 245 / 4887
# inserting column 246 / 4887
# inserting column 247 / 4887
# inserting column 248 / 4887
# inserting column 249 / 4887
# inserting column 250 / 4887
# inserting column 251 / 4887
# inserting column 252 / 4887
# inserting column 253 / 4887
# inserting column 254 / 4887
# inserting column 255 / 4887
# inserting column 256 / 4887
# inserting column 257 / 4887
# inserting column 258 / 4887
# inserting column 259 / 4887
# inserting column 260 / 4887
# inserting column 261 / 4887
# inserting column 262 / 4887
# inserting column 263 / 4887
# inserting column 264 / 4887
# inserting column 265 / 4887
# inserting column 266 / 4887
# inserting column 267 / 4887
# inserting column 268 / 4887
# inserting column 269 / 4887
# inserting column 270 / 4887
# inserting column 271 / 4887
# inserting column 272 / 4887
# inserting column 273 / 4887
# inserting column 274 / 4887
# inserting column 275 / 4887
# inserting column 276 / 4887
# inserting column 277 / 4887
# inserting column 278 / 4887
# inserting column 279 / 4887
# inserting column 280 / 4887
# inserting column 281 / 4887
# inserting column 282 / 4887
# inserting column 283 / 4887
# inserting column 284 / 4887
# inserting column 285 / 4887
# inserting column 286 / 4887
# inserting column 287 / 4887
# inserting column 288 / 4887
# inserting column 289 / 4887
# inserting column 290 / 4887
# inserting column 291 / 4887
# inserting column 292 / 4887
# inserting column 293 / 4887
# inserting column 294 / 4887
# inserting column 295 / 4887
# inserting column 296 / 4887
# inserting column 297 / 4887
# inserting column 298 / 4887
# inserting column 299 / 4887
# inserting column 300 / 4887
# inserting column 301 / 4887
# inserting column 302 / 4887
# inserting column 303 / 4887
# inserting column 304 / 4887
# inserting column 305 / 4887
# inserting column 306 / 4887
# inserting column 307 / 4887
# inserting column 308 / 4887
# inserting column 309 / 4887
# inserting column 310 / 4887
# inserting column 311 / 4887
# inserting column 312 / 4887
# inserting column 313 / 4887
# inserting column 314 / 4887
# inserting column 315 / 4887
# inserting column 316 / 4887
# inserting column 317 / 4887
# inserting column 318 / 4887
# inserting column 319 / 4887
# inserting column 320 / 4887
# inserting column 321 / 4887
# inserting column 322 / 4887
# inserting column 323 / 4887
# inserting column 324 / 4887
# inserting column 325 / 4887
# inserting column 326 / 4887
# inserting column 327 / 4887
# inserting column 328 / 4887
# inserting column 329 / 4887
# inserting column 330 / 4887
# inserting column 331 / 4887
# inserting column 332 / 4887
# inserting column 333 / 4887
# inserting column 334 / 4887
# inserting column 335 / 4887
# inserting column 336 / 4887
# inserting column 337 / 4887
# inserting column 338 / 4887
# inserting column 339 / 4887
# inserting column 340 / 4887
# inserting column 341 / 4887
# inserting column 342 / 4887
# inserting column 343 / 4887
# inserting column 344 / 4887
# inserting column 345 / 4887
# inserting column 346 / 4887
# inserting column 347 / 4887
# inserting column 348 / 4887
# inserting column 349 / 4887
# inserting column 350 / 4887
# inserting column 351 / 4887
# inserting column 352 / 4887
# inserting column 353 / 4887
# inserting column 354 / 4887
# inserting column 355 / 4887
# inserting column 356 / 4887
# inserting column 357 / 4887
# inserting column 358 / 4887
# inserting column 359 / 4887
# inserting column 360 / 4887
# inserting column 361 / 4887
# inserting column 362 / 4887
# inserting column 363 / 4887
# inserting column 364 / 4887
# inserting column 365 / 4887
# inserting column 366 / 4887
# inserting column 367 / 4887
# inserting column 368 / 4887
# inserting column 369 / 4887
# inserting column 370 / 4887
# inserting column 371 / 4887
# inserting column 372 / 4887
# inserting column 373 / 4887
# inserting column 374 / 4887
# inserting column 375 / 4887
# inserting column 376 / 4887
# inserting column 377 / 4887
# inserting column 378 / 4887
# inserting column 379 / 4887
# inserting column 380 / 4887
# inserting column 381 / 4887
# inserting column 382 / 4887
# inserting column 383 / 4887
# inserting column 384 / 4887
# inserting column 385 / 4887
# inserting column 386 / 4887
# inserting column 387 / 4887
# inserting column 388 / 4887
# inserting column 389 / 4887
# inserting column 390 / 4887
# inserting column 391 / 4887
# inserting column 392 / 4887
# inserting column 393 / 4887
# inserting column 394 / 4887
# inserting column 395 / 4887
# inserting column 396 / 4887
# inserting column 397 / 4887
# inserting column 398 / 4887
# inserting column 399 / 4887
# inserting column 400 / 4887
# inserting column 401 / 4887
# inserting column 402 / 4887
# inserting column 403 / 4887
# inserting column 404 / 4887
# inserting column 405 / 4887
# inserting column 406 / 4887
# inserting column 407 / 4887
# inserting column 408 / 4887
# inserting column 409 / 4887
# inserting column 410 / 4887
# inserting column 411 / 4887
# inserting column 412 / 4887
# inserting column 413 / 4887
# inserting column 414 / 4887
# inserting column 415 / 4887
# inserting column 416 / 4887
# inserting column 417 / 4887
# inserting column 418 / 4887
# inserting column 419 / 4887
# inserting column 420 / 4887
# inserting column 421 / 4887
# inserting column 422 / 4887
# inserting column 423 / 4887
# inserting column 424 / 4887
# inserting column 425 / 4887
# inserting column 426 / 4887
# inserting column 427 / 4887
# inserting column 428 / 4887
# inserting column 429 / 4887
# inserting column 430 / 4887
# inserting column 431 / 4887
# inserting column 432 / 4887
# inserting column 433 / 4887
# inserting column 434 / 4887
# inserting column 435 / 4887
# inserting column 436 / 4887
# inserting column 437 / 4887
# inserting column 438 / 4887
# inserting column 439 / 4887
# inserting column 440 / 4887
# inserting column 441 / 4887
# inserting column 442 / 4887
# inserting column 443 / 4887
# inserting column 444 / 4887
# inserting column 445 / 4887
# inserting column 446 / 4887
# inserting column 447 / 4887
# inserting column 448 / 4887
# inserting column 449 / 4887
# inserting column 450 / 4887
# inserting column 451 / 4887
# inserting column 452 / 4887
# inserting column 453 / 4887
# inserting column 454 / 4887
# inserting column 455 / 4887
# inserting column 456 / 4887
# inserting column 457 / 4887
# inserting column 458 / 4887
# inserting column 459 / 4887
# inserting column 460 / 4887
# inserting column 461 / 4887
# inserting column 462 / 4887
# inserting column 463 / 4887
# inserting column 464 / 4887
# inserting column 465 / 4887
# inserting column 466 / 4887
# inserting column 467 / 4887
# inserting column 468 / 4887
# inserting column 469 / 4887
# inserting column 470 / 4887
# inserting column 471 / 4887
# inserting column 472 / 4887
# inserting column 473 / 4887
# inserting column 474 / 4887
# inserting column 475 / 4887
# inserting column 476 / 4887
# inserting column 477 / 4887
# inserting column 478 / 4887
# inserting column 479 / 4887
# inserting column 480 / 4887
# inserting column 481 / 4887
# inserting column 482 / 4887
# inserting column 483 / 4887
# inserting column 484 / 4887
# inserting column 485 / 4887
# inserting column 486 / 4887
# inserting column 487 / 4887
# inserting column 488 / 4887
# inserting column 489 / 4887
# inserting column 490 / 4887
# inserting column 491 / 4887
# inserting column 492 / 4887
# inserting column 493 / 4887
# inserting column 494 / 4887
# inserting column 495 / 4887
# inserting column 496 / 4887
# inserting column 497 / 4887
# inserting column 498 / 4887
# inserting column 499 / 4887
# inserting column 500 / 4887
# inserting column 501 / 4887
# inserting column 502 / 4887
# inserting column 503 / 4887
# inserting column 504 / 4887
# inserting column 505 / 4887
# inserting column 506 / 4887
# inserting column 507 / 4887
# inserting column 508 / 4887
# inserting column 509 / 4887
# inserting column 510 / 4887
# inserting column 511 / 4887
# inserting column 512 / 4887
# inserting column 513 / 4887
# inserting column 514 / 4887
# inserting column 515 / 4887
# inserting column 516 / 4887
# inserting column 517 / 4887
# inserting column 518 / 4887
# inserting column 519 / 4887
# inserting column 520 / 4887
# inserting column 521 / 4887
# inserting column 522 / 4887
# inserting column 523 / 4887
# inserting column 524 / 4887
# inserting column 525 / 4887
# inserting column 526 / 4887
# inserting column 527 / 4887
# inserting column 528 / 4887
# inserting column 529 / 4887
# inserting column 530 / 4887
# inserting column 531 / 4887
# inserting column 532 / 4887
# inserting column 533 / 4887
# inserting column 534 / 4887
# inserting column 535 / 4887
# inserting column 536 / 4887
# inserting column 537 / 4887
# inserting column 538 / 4887
# inserting column 539 / 4887
# inserting column 540 / 4887
# inserting column 541 / 4887
# inserting column 542 / 4887
# inserting column 543 / 4887
# inserting column 544 / 4887
# inserting column 545 / 4887
# inserting column 546 / 4887
# inserting column 547 / 4887
# inserting column 548 / 4887
# inserting column 549 / 4887
# inserting column 550 / 4887
# inserting column 551 / 4887
# inserting column 552 / 4887
# inserting column 553 / 4887
# inserting column 554 / 4887
# inserting column 555 / 4887
# inserting column 556 / 4887
# inserting column 557 / 4887
# inserting column 558 / 4887
# inserting column 559 / 4887
# inserting column 560 / 4887
# inserting column 561 / 4887
# inserting column 562 / 4887
# inserting column 563 / 4887
# inserting column 564 / 4887
# inserting column 565 / 4887
# inserting column 566 / 4887
# inserting column 567 / 4887
# inserting column 568 / 4887
# inserting column 569 / 4887
# inserting column 570 / 4887
# inserting column 571 / 4887
# inserting column 572 / 4887
# inserting column 573 / 4887
# inserting column 574 / 4887
# inserting column 575 / 4887
# inserting column 576 / 4887
# inserting column 577 / 4887
# inserting column 578 / 4887
# inserting column 579 / 4887
# inserting column 580 / 4887
# inserting column 581 / 4887
# inserting column 582 / 4887
# inserting column 583 / 4887
# inserting column 584 / 4887
# inserting column 585 / 4887
# inserting column 586 / 4887
# inserting column 587 / 4887
# inserting column 588 / 4887
# inserting column 589 / 4887
# inserting column 590 / 4887
# inserting column 591 / 4887
# inserting column 592 / 4887
# inserting column 593 / 4887
# inserting column 594 / 4887
# inserting column 595 / 4887
# inserting column 596 / 4887
# inserting column 597 / 4887
# inserting column 598 / 4887
# inserting column 599 / 4887
# inserting column 600 / 4887
# inserting column 601 / 4887
# inserting column 602 / 4887
# inserting column 603 / 4887
# inserting column 604 / 4887
# inserting column 605 / 4887
# inserting column 606 / 4887
# inserting column 607 / 4887
# inserting column 608 / 4887
# inserting column 609 / 4887
# inserting column 610 / 4887
# inserting column 611 / 4887
# inserting column 612 / 4887
# inserting column 613 / 4887
# inserting column 614 / 4887
# inserting column 615 / 4887
# inserting column 616 / 4887
# inserting column 617 / 4887
# inserting column 618 / 4887
# inserting column 619 / 4887
# inserting column 620 / 4887
# inserting column 621 / 4887
# inserting column 622 / 4887
# inserting column 623 / 4887
# inserting column 624 / 4887
# inserting column 625 / 4887
# inserting column 626 / 4887
# inserting column 627 / 4887
# inserting column 628 / 4887
# inserting column 629 / 4887
# inserting column 630 / 4887
# inserting column 631 / 4887
# inserting column 632 / 4887
# inserting column 633 / 4887
# inserting column 634 / 4887
# inserting column 635 / 4887
# inserting column 636 / 4887
# inserting column 637 / 4887
# inserting column 638 / 4887
# inserting column 639 / 4887
# inserting column 640 / 4887
# inserting column 641 / 4887
# inserting column 642 / 4887
# inserting column 643 / 4887
# inserting column 644 / 4887
# inserting column 645 / 4887
# inserting column 646 / 4887
# inserting column 647 / 4887
# inserting column 648 / 4887
# inserting column 649 / 4887
# inserting column 650 / 4887
# inserting column 651 / 4887
# inserting column 652 / 4887
# inserting column 653 / 4887
# inserting column 654 / 4887
# inserting column 655 / 4887
# inserting column 656 / 4887
# inserting column 657 / 4887
# inserting column 658 / 4887
# inserting column 659 / 4887
# inserting column 660 / 4887
# inserting column 661 / 4887
# inserting column 662 / 4887
# inserting column 663 / 4887
# inserting column 664 / 4887
# inserting column 665 / 4887
# inserting column 666 / 4887
# inserting column 667 / 4887
# inserting column 668 / 4887
# inserting column 669 / 4887
# inserting column 670 / 4887
# inserting column 671 / 4887
# inserting column 672 / 4887
# inserting column 673 / 4887
# inserting column 674 / 4887
# inserting column 675 / 4887
# inserting column 676 / 4887
# inserting column 677 / 4887
# inserting column 678 / 4887
# inserting column 679 / 4887
# inserting column 680 / 4887
# inserting column 681 / 4887
# inserting column 682 / 4887
# inserting column 683 / 4887
# inserting column 684 / 4887
# inserting column 685 / 4887
# inserting column 686 / 4887
# inserting column 687 / 4887
# inserting column 688 / 4887
# inserting column 689 / 4887
# inserting column 690 / 4887
# inserting column 691 / 4887

# %%
data.shape

# %% [markdown]
# We have the final dataset, let's save it to a CSV file. *TODO: The following code block raises an **IndexError** *

# %%
# %%time
data.to_csv('../data/hashtags_binarized.csv', index=False)
